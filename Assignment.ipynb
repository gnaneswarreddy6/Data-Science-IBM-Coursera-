# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Gnaneswar Reddy**
#   <br>
#   Student

# %% [markdown]
# *I am intrested in data Science because of the insights from data*

# %% [markdown]
# ###Print my name

# %%
print("Gnaneswar")
# Out:
# Gnaneswar

# %% [markdown]
# http://www.google.com
#
# | Tables        | Are           | Cool  |
# | ------------- |:-------------:| -----:|
# | zebra stripes | are neat      |    $1 |
#
# 1. he
# 2. she
# 3. we
